# %% [markdown]
# # Western Australia Rental Prices - Extract
#
# https://www.kaggle.com/c/deloitte-western-australia-rental-prices/

# %%
# imports
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division
from sklearn import preprocessing
# %matplotlib inline

# %%
# settings and constants
# %logstop
# %logstart  -o 'Extract' rotate
plt.rcParams['figure.figsize'] = (10.0, 8.0)
pd.set_option('display.max_rows', 50)
start_time = pd.datetime.now()
print start_time
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : Extract
# Mode           : rotate
# Output logging : True
# Raw input log  : False
# Timestamping   : False
# State          : active
# 2015-11-25 12:18:03.357540

# %%
# based on Mac with Postgres.app
# export PATH="/Applications/Postgres.app/Contents/Versions/9.4/bin:$PATH"
# then pip install psycopg2
# then sudo brew install openssl
# and follow these instructions:
# http://stackoverflow.com/questions/11365619/psycopg2-installation-error-library-not-loaded-libssl-dylib

from sqlalchemy import create_engine
engine = create_engine('postgresql://paulperry:ciao,ciao@localhost:5432/australia', 
                       connect_args={'client_encoding': 'latin1'})

# %% [markdown]
# # EXTRACT

# %%
train = pd.read_csv('data/train.csv', low_memory=False)
print train.shape
# Out:
# (834570, 5)

# %%
train.columns = map(str.lower, train.columns)
train.set_index('ren_id', inplace=True)
train.ren_date_eff_from = pd.to_datetime(train.ren_date_eff_from)
train[:2]
# Out:
#         ren_date_eff_from  ren_base_rent  ve_number ren_lease_length
# ren_id
# 1579258        1990-02-13            280    4807702              NaN
# 1203979        1990-04-13            115     332135              NaN

# %%
#train = pd.read_csv('data/train.csv', low_memory=False)
test = pd.read_csv('data/test.csv', low_memory=False)
print test.shape
# Out:
# (150508, 4)

# %%
test.columns = map(str.lower, test.columns)
test.set_index('ren_id', inplace=True)
test.ren_date_eff_from = pd.to_datetime(test.ren_date_eff_from)
test[:2]
# Out:
#        ren_date_eff_from  ve_number ren_lease_length
# ren_id
# 10568         2004-02-18    2402939              NaN
# 12686         2004-02-18    1352438              NaN

# %% [markdown]
# ## Quantity Features

# %%
# get all the quantities 

qp1 = "select t1.ren_id, t1.ve_number, t2.urv_id, t2.uvv_date_eff_from, t2.uvv_quantity from " # query part 1
qp2 = " t1 join (select distinct on (ve_number, urv_id) ve_number, urv_id, uvv_date_eff_from, uvv_quantity \
        from valuation_entities_details \
        where urv_ven_quality_ind like 'N' and urv_ven_quantity_ind like 'Y' and uvv_quantity is not null \
        group by ve_number, urv_id, uvv_date_eff_from, uvv_quantity \
        order by ve_number, urv_id, uvv_date_eff_from desc) t2  \
        on( t1.ve_number = t2.ve_number and t1.ren_date_eff_from > t2.uvv_date_eff_from and urv_id is not null)"
qp3 = ";"

fullq = qp1+'train'+qp2+' union all '+qp1+'test'+qp2+qp3

# %time ve_quantity = pd.read_sql_query(fullq, engine)
print ve_quantity.shape
ve_quantity[:5]
# Out:
# CPU times: user 20.9 s, sys: 3.21 s, total: 24.1 s
# Wall time: 1min 44s
# (7597821, 5)
#     ren_id  ve_number  urv_id uvv_date_eff_from  uvv_quantity
# 0  2391247         61      19        2000-07-01          60.0
# 1  2391247         61      58        1986-07-01           2.0
# 2  2658991         61      58        1986-07-01           2.0
# 3   890584         61      58        1986-07-01           2.0
# 4  2391247         61     206        1986-07-01           3.5

# %%
# # this confirmed there are no duplicate ren_id's for the same date in this table
# vegroup = ve_quantity.groupby(['ren_id','ve_number','urv_id', 'uvv_date_eff_from']).count().sort_values('uvv_quantity',ascending=False)
# vegroup[:5]
# # if there are dupes, I would eliminate this way:
# print len(ve_quantity.index)
# ve_quantity.drop_duplicates(['ren_id','ve_number','urv_id'], keep='first', inplace=True)
# print len(ve_quantity.index)

# %%
quantity_features = pd.pivot(ve_quantity.ren_id, ve_quantity.urv_id, ve_quantity.uvv_quantity)
quantity_features.iloc[:5]
# Out:
# /Users/paulperry/anaconda/lib/python2.7/site-packages/pandas/core/index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
# urv_id  4    5    19   20   21   23   24   25   26   28  ...   405  413  431  \
# ren_id                                                   ...
# 6         1  NaN  217  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 9       NaN  NaN  119  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 13      NaN  NaN   60  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 26        1  NaN  120  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 27      NaN  NaN   78  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
#
# urv_id  434  440  441  443  444  477  479
# ren_id
# 6         1  NaN  NaN    1  NaN  NaN  NaN
# 9       NaN  NaN  NaN    1  NaN  NaN  NaN
# 13      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 73 columns]

# %%
# stop if somehow we messed up the pivot
if len(quantity_features.index) > (len(train.index)+len(test.index)):
    raise Exception('bad pivot')

# %%
# # generate the ve_keys if we don't have the file
# q_key ="select urv_id, urv_description, urv_ven_quality_ind, urv_ven_quantity_ind, count(*) as c \
#     from valuation_entities_details \
#     group by urv_id, urv_description, urv_ven_quality_ind, urv_ven_quantity_ind \
#     order by c desc;"

# ve_key = pd.read_sql_query(q_key, engine)
# ve_key.to_csv('ve_key.csv', index=False)
# print len(ve_key.index)
# ve_key.iloc[:10]

# %%
# load the valuation entity keys
ve_key = pd.read_csv('ve_key.csv')
ve_key.set_index('urv_id', inplace=True)
ve_key[:5]
# Out:
#         urv_description urv_ven_quality_ind urv_ven_quantity_ind        c
# urv_id
# 206     EFFECTIVE ROOMS                   N                    Y  1034318
# 58             BEDROOMS                   N                    Y   924250
# 410          YEAR BUILT                   Y                    N   923596
# 271             KITCHEN                   N                    Y   858940
# 89         BRICK  WALLS                   N                    N   789499

# %%
def rename_columns(df):
    # map columns to ve_key names
    col_names = [ve_key.loc[i].urv_description.lower().replace(' ','_').replace('-','_') 
                 for i in df.columns]
    col_names = [s.encode('ascii','ignore') for s in col_names]
    col_names = [c.translate(None,".()&?!;$/\\,") for c in col_names]
    if len(col_names) == len(df.columns):
        df.columns = col_names
    else:
        raise Exception('Problem renaming columns!') 

    return df

# %%
quantity_features.columns
# Out:
# Int64Index([  4,   5,  19,  20,  21,  23,  24,  25,  26,  28,  29,  30,  31,
#              33,  56,  57,  58,  59,  69,  70,  71,  73,  74,  75, 201, 203,
#             206, 210, 214, 216, 224, 227, 229, 230, 232, 233, 234, 236, 267,
#             271, 272, 280, 283, 284, 291, 292, 318, 331, 340, 344, 345, 356,
#             361, 366, 367, 368, 369, 370, 371, 372, 387, 403, 404, 405, 413,
#             431, 434, 440, 441, 443, 444, 477, 479],
#            dtype='int64', name=u'urv_id')

# %%
quantity_features = rename_columns(quantity_features)
print quantity_features.columns
# Out:
# Index([u'activity_room', u'airconditioned', u'house_area', u'office_area_1',
#        u'shop_area', u'store_room_area_1', u'warehouse_area_1',
#        u'factory_area_1', u'any_other_area', u'basement_area', u'shed_area_1',
#        u'total_area', u'mezzanine_area', u'workshop_area_1', u'bar',
#        u'bath_room', u'bedrooms', u'single_bedrooms', u'carbay_under_cover',
#        u'tandem_carbay', u'open_car_bay', u'carport_under_main_roof',
#        u'carport_attached', u'carport_detached', u'dining_room',
#        u'dressing_room', u'effective_rooms', u'ensuite', u'excess_land',
#        u'family_room', u'frontage_of_block', u'fronts_onto_lake',
#        u'games__room', u'detached_gamesroom', u'garage_under_main_roof',
#        u'garage_attached', u'garage_detached', u'guest_room', u'kennels',
#        u'kitchen', u'laundry', u'lounge_room', u'meals_area', u'music_room',
#        u'other_rooms', u'plate_height', u'parents__retreat', u'sleep_out',
#        u'sewing_room', u'shed', u'sitting_room', u'spa_room', u'stable',
#        u'store_room', u'storey', u'studio', u'study', u'sun_room',
#        u'television_room', u'tennis_court', u'number_of_units', u'toilet',
#        u'walk_in_robe', u'workshop', u'effective_bed_count', u'ven_land_area',
#        u'theatre_room', u'hall_area', u'jetty', u'alfresco_room',
#        u'kitchenette', u'area_of_sheds', u'scullery'],
#       dtype='object')

# %%
print quantity_features.shape
# Out:
# (979255, 73)

# %%
quantity_features.count().sort_values(ascending=False)
# Out:
# bedrooms                   931557
# effective_rooms            834353
# kitchen                    827811
# lounge_room                763260
# house_area                 690340
# dining_room                525876
# bath_room                  346280
# toilet                     312093
# family_room                297204
# ensuite                    279033
# carport_under_main_roof    224964
# storey                     212683
# walk_in_robe               200900
# garage_under_main_roof     168170
# meals_area                 161340
# carport_detached           112629
# store_room                 103041
# games__room                 93795
# carport_attached            86176
# garage_detached             72513
# study                       65796
# alfresco_room               40300
# garage_attached             33340
# effective_bed_count         30775
# theatre_room                30765
#                             ...
# dressing_room                 279
# music_room                    272
# office_area_1                 271
# shop_area                     215
# television_room               212
# laundry                       179
# guest_room                    154
# detached_gamesroom            153
# store_room_area_1             149
# jetty                          94
# tandem_carbay                  91
# workshop_area_1                87
# area_of_sheds                  86
# kitchenette                    82
# plate_height                   46
# factory_area_1                 27
# kennels                        12
# fronts_onto_lake               11
# ven_land_area                   8
# warehouse_area_1                4
# scullery                        3
# mezzanine_area                  3
# hall_area                       2
# single_bedrooms                 2
# basement_area                   1
# dtype: int64

# %%
def df_summary(df):
    features = []
    for c in df.columns:
        unique = len(df[c].unique())
        vals =  df[c].notnull().sum()
        example = df[c].unique()[:9]
        features.append([c, unique, vals, example])
    df_features = pd.DataFrame(features, columns=['feature','unique','count','example_values'])
    return df_features.sort_values(by='unique', ascending=False)

# %%
df_summary(quantity_features)
# Out:
#                    feature  unique   count  \
# 2               house_area   11905  690340
# 30       frontage_of_block    1364   21738
# 10             shed_area_1     195    1401
# 8           any_other_area     154   20358
# 26         effective_rooms      81  834353
# 3            office_area_1      66     271
# 71           area_of_sheds      51      86
# 13         workshop_area_1      39      87
# 60         number_of_units      29    5243
# 11              total_area      29     704
# 4                shop_area      25     215
# 28             excess_land      24     978
# 54                  storey      22  212683
# 5        store_room_area_1      19     149
# 52                  stable      17     389
# 16                bedrooms      16  931557
# 49                    shed      15    3930
# 61                  toilet      13  312093
# 44             other_rooms      12   16493
# 34  garage_under_main_roof      12  168170
# 23        carport_detached      11  112629
# 27                 ensuite      11  279033
# 53              store_room      11  103041
# 36         garage_detached      10   72513
# 62            walk_in_robe      10  200900
# ..                     ...     ...     ...
# 50            sitting_room       5    4781
# 57                sun_room       4     852
# 66            theatre_room       4   30765
# 55                  studio       3    1552
# 0            activity_room       3   13666
# 51                spa_room       3    1701
# 33      detached_gamesroom       3     153
# 6         warehouse_area_1       3       4
# 12          mezzanine_area       3       3
# 14                     bar       3     838
# 17         single_bedrooms       3       2
# 25           dressing_room       3     279
# 40                 laundry       3     179
# 46        parents__retreat       3    6713
# 37              guest_room       2     154
# 59            tennis_court       2    1760
# 31        fronts_onto_lake       2      11
# 48             sewing_room       2     344
# 58         television_room       2     212
# 43              music_room       2     272
# 67               hall_area       2       2
# 68                   jetty       2      94
# 9            basement_area       2       1
# 70             kitchenette       2      82
# 72                scullery       2       3
#
#                                        example_values
# 2   [217.0, 119.0, 60.0, 120.0, 78.0, 114.0, nan, ...
# 30  [nan, 18.0, 20.48, 20.12, 18.61, 34.41, 10.06,...
# 10  [nan, 36.0, 72.0, 14.6, 54.0, 198.0, 46.2, 90....
# 8   [nan, 41.0, 64.0, 220.0, 130.0, 61.6, 68.0, 48...
# 26     [11.0, 7.0, 4.0, 6.5, 4.5, 6.0, 9.5, 2.5, 9.0]
# 3   [nan, 135.0, 110.0, 1.0, 120.0, 35.0, 139.0, 1...
# 71  [nan, 72.0, 38.0, 30.0, 54.0, 25.0, 32.0, 74.0...
# 13  [nan, 60.0, 17.0, 169.0, 50.0, 99.0, 108.0, 20...
# 60   [nan, 2.0, 4.0, 8.0, 12.0, 3.0, 11.0, 10.0, 5.0]
# 11  [nan, 96.0, 73.0, 85.0, 88.0, 95.0, 100.0, 187...
# 4   [nan, 32.0, 81.0, 38.0, 40.0, 96.0, 68.0, 150....
# 28      [nan, 2.0, 1.0, 4.0, 3.0, 6.0, 0.4, 5.0, 2.5]
# 54    [1.25, nan, 2.0, 1.0, 3.0, 1.5, 4.0, 5.0, 1.75]
# 5   [nan, 4.0, 3.0, 1.0, 2.0, 5.0, 290.0, 22.0, 30...
# 52     [nan, 2.0, 4.0, 1.0, 3.0, 8.0, 5.0, 10.0, 6.0]
# 16      [4.0, 3.0, 2.0, 1.0, nan, 6.0, 5.0, 7.0, 8.0]
# 49  [nan, 1.0, 2.0, 5.0, 18.0, 3.0, 7.0, 162.0, 36.0]
# 61     [2.0, nan, 1.0, 3.0, 5.0, 4.0, 21.0, 6.0, 7.0]
# 44     [nan, 1.0, 2.0, 5.0, 2.5, 32.0, 3.0, 4.0, 6.0]
# 34    [2.0, nan, 1.0, 3.0, 4.0, 12.0, 5.0, 22.0, 8.0]
# 23     [nan, 1.0, 2.0, 6.0, 3.0, 5.0, 16.0, 7.0, 4.0]
# 27      [1.0, nan, 2.0, 4.0, 3.0, 6.0, 0.0, 5.0, 1.5]
# 53   [nan, 1.0, 2.0, 3.0, 5.0, 1.5, 0.5, 13.0, 12.25]
# 36     [nan, 1.0, 2.0, 3.0, 5.0, 4.0, 6.0, 30.0, 9.0]
# 62    [4.0, 1.0, nan, 2.0, 3.0, 5.0, 6.0, 11.0, 23.0]
# ..                                                ...
# 50                        [nan, 1.0, 2.0, 1.5, 167.0]
# 57                               [nan, 1.0, 2.0, 0.5]
# 66                               [1.0, nan, 2.0, 1.5]
# 55                                    [nan, 1.0, 1.5]
# 0                                     [1.0, nan, 2.0]
# 51                                    [nan, 1.0, 2.0]
# 33                                    [nan, 1.0, 2.0]
# 6                                [nan, 240.53, 358.0]
# 12                                   [nan, 1.0, 40.0]
# 14                                    [nan, 1.0, 2.0]
# 17                                    [nan, 3.0, 2.0]
# 25                                    [nan, 1.0, 2.0]
# 40                                    [nan, 1.0, 2.0]
# 46                                    [1.0, nan, 2.0]
# 37                                         [nan, 1.0]
# 59                                         [nan, 1.0]
# 31                                         [nan, 1.0]
# 48                                         [nan, 1.0]
# 58                                         [nan, 1.0]
# 43                                         [nan, 1.0]
# 67                                       [nan, 130.0]
# 68                                         [nan, 1.0]
# 9                                          [nan, 6.0]
# 70                                         [nan, 1.0]
# 72                                         [nan, 1.0]
#
# [73 rows x 4 columns]

# %%
quantity_features[:5]
# Out:
#         activity_room  airconditioned  house_area  office_area_1  shop_area  \
# ren_id
# 6                   1             NaN         217            NaN        NaN
# 9                 NaN             NaN         119            NaN        NaN
# 13                NaN             NaN          60            NaN        NaN
# 26                  1             NaN         120            NaN        NaN
# 27                NaN             NaN          78            NaN        NaN
#
#         store_room_area_1  warehouse_area_1  factory_area_1  any_other_area  \
# ren_id
# 6                     NaN               NaN             NaN             NaN
# 9                     NaN               NaN             NaN             NaN
# 13                    NaN               NaN             NaN             NaN
# 26                    NaN               NaN             NaN             NaN
# 27                    NaN               NaN             NaN             NaN
#
#         basement_area    ...     workshop  effective_bed_count  ven_land_area  \
# ren_id                   ...
# 6                 NaN    ...          NaN                  NaN            NaN
# 9                 NaN    ...          NaN                  NaN            NaN
# 13                NaN    ...          NaN                  NaN            NaN
# 26                NaN    ...          NaN                  NaN            NaN
# 27                NaN    ...          NaN                  NaN            NaN
#
#         theatre_room  hall_area  jetty  alfresco_room  kitchenette  \
# ren_id
# 6                  1        NaN    NaN              1          NaN
# 9                NaN        NaN    NaN              1          NaN
# 13               NaN        NaN    NaN            NaN          NaN
# 26               NaN        NaN    NaN            NaN          NaN
# 27               NaN        NaN    NaN            NaN          NaN
#
#         area_of_sheds  scullery
# ren_id
# 6                 NaN       NaN
# 9                 NaN       NaN
# 13                NaN       NaN
# 26                NaN       NaN
# 27                NaN       NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# ## Quality Features

# %%
# get all the qualities 

qq1 = "select t1.ren_id, t1.ve_number, t2.urv_id, t2.uvv_date_eff_from, t2.uvv_quality from " # query part 1
qq2 = " t1 join (select distinct on (ve_number, urv_id) ve_number, urv_id, uvv_date_eff_from, uvv_quality \
        from valuation_entities_details \
        where urv_ven_quality_ind like 'Y' and urv_ven_quantity_ind like 'N' and uvv_quality <> '' \
        group by ve_number, urv_id, uvv_date_eff_from, uvv_quality \
        order by ve_number, urv_id, uvv_date_eff_from desc) t2  \
        on( t1.ve_number = t2.ve_number and t1.ren_date_eff_from > t2.uvv_date_eff_from )"
qq3 = ";"

fullqq = qq1+'train'+qq2+' union all '+qq1+'test'+qq2+qq3

# %time ve_quality = pd.read_sql_query(fullqq, engine)
# Out:
# CPU times: user 3.35 s, sys: 198 ms, total: 3.55 s
# Wall time: 24.3 s

# %%
print ve_quality.shape
ve_quality[:5]
# Out:
# (1489542, 5)
#     ren_id  ve_number  urv_id uvv_date_eff_from uvv_quality
# 0  1184400       2125      82        1986-07-01        FAIR
# 1  1184400       2125     410        1986-07-01        1975
# 2  4653370       3861      82        1986-07-01        FAIR
# 3  4579201       3861      82        1986-07-01        FAIR
# 4  3880378       3861      82        1986-07-01        FAIR

# %%
# one dupe?
print len(ve_quality.index)
ve_quality.drop_duplicates(['ren_id','ve_number','urv_id'], keep='first', inplace=True)
print len(ve_quality.index)
# Out:
# 1489542
# 1489541

# %%
quality_features = ve_quality.pivot('ren_id', 'urv_id', 'uvv_quality')
quality_features.iloc[:5]
# Out:
# urv_id   82    410  411
# ren_id
# 6        NaN  2010  NaN
# 9        NaN  2010  NaN
# 13      FAIR  1976  NaN
# 26       NaN  2008  NaN
# 27      FAIR  1981  NaN

# %%
quality_features = rename_columns(quality_features)
print quality_features.columns
# Out:
# Index([u'condition', u'year_built', u'year_effective'], dtype='object')

# %%
quality_features[:5]
# Out:
#        condition year_built year_effective
# ren_id
# 6            NaN       2010            NaN
# 9            NaN       2010            NaN
# 13          FAIR       1976            NaN
# 26           NaN       2008            NaN
# 27          FAIR       1981            NaN

# %% [markdown]
# ## Dummy Features

# %%
# get all the dummy features 

qr1 = "select t1.ren_id, t1.ve_number, t2.urv_id, t2.uvv_date_eff_from, t2.uvv_quality, t2.uvv_quantity from " 
qr2 = " t1 join (select distinct on (ve_number, urv_id) \
        ve_number, urv_id, uvv_date_eff_from, uvv_quality, uvv_quantity \
        from valuation_entities_details \
        where urv_ven_quality_ind like 'N' and urv_ven_quantity_ind like 'N'  \
        group by ve_number, urv_id, uvv_date_eff_from, uvv_quality, uvv_quantity \
        order by ve_number, urv_id, uvv_date_eff_from desc) t2  \
        on( t1.ve_number = t2.ve_number and t1.ren_date_eff_from > t2.uvv_date_eff_from )"
qr3 = ";"

fullqr = qr1+'train'+qr2+' union all '+qr1+'test'+qr2+qr3

# %time ve_dummy = pd.read_sql_query(fullqr, engine)
# Out:
# CPU times: user 6.44 s, sys: 494 ms, total: 6.93 s
# Wall time: 32.4 s

# %%
print ve_dummy.shape
ve_dummy[:5]
# Out:
# (2327154, 6)
#     ren_id  ve_number  urv_id uvv_date_eff_from uvv_quality  uvv_quantity
# 0  2391247         61      89        1986-07-01                       NaN
# 1  2658991         61      89        1986-07-01                       NaN
# 2   890584         61      89        1986-07-01                       NaN
# 3  2391247         61     195        2004-07-01                       NaN
# 4  2391247         61     321        1986-07-01                       NaN

# %%
# drop duplicates: 3 of them.
print len(ve_dummy.index)
ve_dummy.drop_duplicates(['ren_id', 've_number','urv_id'], keep='first', inplace=True)
print len(ve_dummy.index)
# Out:
# 2327154
# 2327151

# %%
# we could look at the values, but we move on
#ve_dummy[ve_dummy.uvv_quantity.notnull()].sort_values(by='uvv_quantity', ascending=False)[:10]

# %%
dummy_quantity = ve_dummy[ve_dummy.uvv_quantity.notnull()].pivot('ren_id', 'urv_id', 'uvv_quantity')
dummy_quantity.iloc[:5]
# Out:
# urv_id  6    7    8    9    10   11   12   13   14   17  ...   322  329  332  \
# ren_id                                                   ...
# 147     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 317     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 379     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 380     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 513     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
#
# urv_id  355  388  389  391  392  393  476
# ren_id
# 147     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 317     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 379     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 380     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 513     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 65 columns]

# %%
print dummy_quantity.shape
# Out:
# (47543, 65)

# %%
dummy_quantity = rename_columns(dummy_quantity)

# %%
dummy_quantity.notnull().sum().sort_values(ascending=False)
# Out:
# bore                       27511
# below_ground_pool          13855
# other_extra                 4076
# lift                        2574
# sauna                       1162
# loft                         375
# lotdth                       339
# enclosed_back_veranda        193
# office                       192
# cabana                       187
# open_patio                   187
# enclosed_front_veranda       180
# rumpus_room                  169
# enclosed_patio               168
# airconditioned_ducted        148
# cellar                       112
# reticulation                  89
# pantry                        87
# utility_room                  79
# atrium                        75
# gymnasium                     58
# playroom                      56
# above_ground_pool             41
# attic                         28
# proximity_to_city             25
#                            ...
# no_airconditioning             4
# close_to_church                4
# river_views                    4
# busy_road                      3
# gazebo                         3
# fibro_roof                     2
# wall_airconditioning           2
# foyer                          2
# iron_roof                      2
# train_stop                     1
# church                         1
# solarium                       1
# liquor_outlet                  1
# secondary_school               1
# bus_stop                       1
# shops                          1
# public_park                    1
# tile_roof                      1
# house                          1
# busy_intersection              1
# big_rooms                      1
# building_frontage              1
# lake__views                    1
# max__value_for_carcover        1
# extra_land                     1
# dtype: int64

# %%
ve_dummy[:5]
# Out:
#     ren_id  ve_number  urv_id uvv_date_eff_from uvv_quality  uvv_quantity
# 0  2391247         61      89        1986-07-01                       NaN
# 1  2658991         61      89        1986-07-01                       NaN
# 2   890584         61      89        1986-07-01                       NaN
# 3  2391247         61     195        2004-07-01                       NaN
# 4  2391247         61     321        1986-07-01                       NaN

# %%
# We keep a dummy variable
ve_dummy.uvv_quality = '1'

dummy_quality = ve_dummy[ve_dummy.uvv_quantity.isnull()].pivot('ren_id', 'urv_id', 'uvv_quality')
dummy_quality.iloc[:5]
# Out:
# urv_id  1    2    3    6    13   15   16   17   18   35  ...   445  446  448  \
# ren_id                                                   ...
# 6       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 9       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 13      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 26      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
# 27      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
#
# urv_id  449  453  454  455  456  457  476
# ren_id
# 6       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 236 columns]

# %%
print dummy_quality.shape
# Out:
# (976583, 236)

# %%
dummy_quality = rename_columns(dummy_quality)

# %%
# let's see what they look like
dummy_quality.count().sort_values(ascending=False)
# Out:
# brick__walls                867341
# tile_roof                   700370
# iron_roof                   171179
# street_allowance             99128
# big_rooms                    41953
# fibro_walls                  35889
# brick_veneer                 35685
# standard_of_finish           31469
# below_ground_pool            31125
# small_rooms                  28833
# fibro_roof                   26660
# general_views                16313
# weather_board_walls          15631
# river_views                  13481
# ocean_views                  11930
# precast_concrete_walls       10410
# _community_facilities        10378
# airconditioned_ducted         9348
# common_walls                  7532
# located_at_rear               7378
# inferior_location             6558
# timber_frame                  6169
# general_attributes            6095
# rear_units                    5824
# location                      5772
#                              ...
# gravel_soil                      3
# public_toilet                    3
# no_onsite_carpark                3
# lot_has_hill__views              2
# street_access                    2
# non_conforming_use               2
# less_than_norm_bedrooms          2
# library                          2
# lot_has_city_views               2
# dual_c_way                       2
# surgery                          2
# unit_position                    2
# age_of_buildings                 2
# lotdth                           2
# property_exposed_to_dust         2
# wet_soil                         1
# rocky_soil                       1
# phone_tower                      1
# shade_house                      1
# low_lying_land                   1
# infant_health_centre             1
# spur_access                      1
# unit_position_corner             1
# change_room                      1
# max__value_for_carcover          1
# dtype: int64

# %%
# NOTE: This bus_stop feature appears twice and may need to be dropped but is not a high count
print 'bus_stop: ', dummy_quality['bus_stop'].iloc[:,0].notnull().sum()
# remove the duplicate columns
dummy_quality.drop(['bus_stop'], axis=1, inplace=True)
# Out:
# bus_stop:  9

# %%
print dummy_quality.columns.values
# Out:
# ['dual_access' 'street_access' 'row_access' 'airconditioned_ducted'
#  'library' 'public_pool' 'public_park' 'community_centre'
#  'lot_has_city_views' 'lot_has_river_views' 'lot_has_ocean_views'
#  'lot_has_land__views' 'lot_has_hill__views' 'lot_looks_over_a_park'
#  'atrium' 'attic' 'general_attributes' 'extra_land' 'big_rooms'
#  'large_shed' 'age_of_buildings' '_community_facilities' 'river_frontage'
#  'canals_frontage' 'close_to_park' 'boat_shed' 'bore' 'cold_room' 'cabana'
#  'canal_frontage' 'max__value_for_carcover' 'cellar' 'character'
#  'change_room' 'steel_frame_and_iron_wall' 'iron_walls' 'stone_walls'
#  'concrete_block_walls' 'brick__walls' 'steel_frame' 'timber_frame'
#  'brick_veneer' 'weather_board_walls' 'other' 'brick_clad'
#  'brick__iron_walls' 'stucco_walls' 'brick_walls_timber_frame'
#  'brick__weathboard_walls' 'fibro_walls' 'rammed_earth'
#  'precast_concrete_walls' 'limestone' 'design' 'block_of_flats'
#  'service_station' 'public_toilet' 'sump' 'hotel' 'transformer'
#  'kindergarden' 'close_to_church' 'infant_health_centre' 'telephone_box'
#  'traffic_lights' 'bus_shelter' 'school' 'non_conforming_use'
#  'caravan_park' 'bmx_track' 'car_park' 'drain' 'surgery' 'lights'
#  'industrial_property' 'railway' 'recreation_centre' 'depot'
#  'no_airconditioning' 'hospital' 'poor_access' 'inferior_location'
#  'power_station' 'oval' 'general_detriments' 'public_hall' 'cemetary'
#  'commercial_building' 'traffic_noise' 'traffic_island' 'rear_units'
#  'graveyard' 'isolated_location' 'property_exposed_to_dust'
#  'close_to_commercial_area' 'next_to_bowling_club' 'age_of_building'
#  'adj_public_open_space' 'pedestrian_access_way' 'shops' 'small_rooms'
#  'freeway' 'upper_floor' 'tennissquash_courts' 'old_age_home' 'club'
#  'busy_intersection' 'size_of_block' 'community_facilities' 'restaurant'
#  'police_station' 'pump_station' '_shopping_centre' 'gaol' 'busy_road'
#  'flood_prone' 'on_an_island_no_vehicle_a' 'wall_airconditioning'
#  'less_than_norm_bedrooms' 'construction_type' 'reduced_area'
#  'common_walls' 'buildings_lack_utility' 'low_lying_land' 'bulk_allowance'
#  'overhead_power_lines' 'enclosed_back_veranda' 'enclosed_front_veranda'
#  'high_elevation' 'low__elevation' 'entry' 'enclosed_side_veranda' 'foyer'
#  'gallery' 'gazebo' 'gymnasium' 'hall' 'house' 'kerb_and_drainage'
#  'not_kerb_and_drainage' 'lift' 'corner_location' 'location_of_property'
#  'location' 'loft' 'lotdth' 'other_extra' 'office' 'pantry'
#  'enclosed_patio' 'open_patio' 'playroom' 'below_ground_pool'
#  'above_ground_pool' 'bitumen' 'gravel_road' 'street_road_type' 'culdesac'
#  'dual_c_way' 'above_road' 'below_road' 'reticulation' 'tile_roof'
#  'iron_roof' 'aluminium_roof' 'other_roof_type' 'decromastic_tile'
#  'metal_decking' 'rumpus_room' 'spur_access' 'sauna'
#  'storm_water_available' 'shade_house' 'no_slope' 'front_to_rear_slope'
#  'rear_to_front_slope' 'wet_soil' 'dry_soil' 'rocky_soil' 'sandy_soil'
#  'gravel_soil' 'other__soil' 'solarium' 'street_allowance' 'street_parking'
#  'horse_stall' 'standard_of_finish' 'character_standard_of_fin'
#  'unit_position_front' 'unit_position_rear' 'unit_position_corner'
#  'unit_position__corner' 'unit_position_ground' 'unit_position_first_floor'
#  'unit_position_second_floo' 'unit_position_third_floor'
#  'unit_position_upper_floor' 'unit_position_middle' 'utility_room'
#  'vestibule' 'city_views' 'river_views' 'ocean_views' 'lake__views'
#  'land_views' 'hill_views' 'park_views' 'valley_views' 'harbour_views'
#  'estuary_views' 'general_views' 'water_tank' 'flat'
#  'cross_fall_left_to_right' 'cross_fall_right_to_left' 'smaller_lot_size'
#  'unusual_design' 'sporting_facility' 'located_at_rear'
#  'traffic_noisesafety' 'no_onsite_carpark' "restricted_to_over_55's"
#  'studio_detached' "max_depc'n_govt_asset" 'unit_position' 'laneway'
#  'phone_tower' 'marina_views' 'brick__fibro_walls' 'timber_frame__fibro_w'
#  'timber_framebrickfib_wa' 'steel_frame_and_fibro' 'weatherboardfibro_wall'
#  'fibro_roof']

# %%
# remove the columns in quality that are already reflected in quantity
dummy_overlap = set(dummy_quality.columns) & set(dummy_quantity.columns)
print dummy_overlap
for o in dummy_overlap:
    dummy_quality.drop(o, axis=1, inplace=True)
print set(dummy_quality.columns) & set(dummy_quantity.columns)
# Out:
# set(['office', 'attic', 'house', 'gymnasium', 'enclosed_back_veranda', 'airconditioned_ducted', 'iron_roof', 'service_station', 'atrium', 'bore', 'enclosed_patio', 'general_detriments', 'loft', 'wall_airconditioning', 'enclosed_front_veranda', 'solarium', 'cabana', 'hall', 'busy_intersection', 'tile_roof', 'utility_room', 'reticulation', 'max__value_for_carcover', 'fibro_roof', 'lake__views', 'shops', 'ocean_views', 'river_views', 'cellar', 'above_ground_pool', 'lotdth', 'large_shed', 'big_rooms', 'rumpus_room', 'rear_units', 'other_extra', 'lift', 'pantry', 'entry', 'extra_land', 'sauna', 'gallery', 'close_to_church', 'playroom', 'gazebo', 'open_patio', 'busy_road', 'vestibule', 'no_airconditioning', 'below_ground_pool', 'foyer', 'public_park', 'enclosed_side_veranda'])
# set([])

# %%
# let's see if the deleted columns in quality are really in quantity
dummy_quantity.columns
# Out:
# Index([u'airconditioned_ducted', u'shopping_centre', u'church',
#        u'service_station', u'liquor_outlet', u'primary_school',
#        u'secondary_school', u'bus_stop', u'train_stop', u'public_park',
#        u'atrium', u'attic', u'extra_land', u'big_rooms', u'large_shed',
#        u'building_depth', u'building_frontage', u'bore', u'cabana',
#        u'max__value_for_carcover', u'cellar', u'close_to_church',
#        u'no_airconditioning', u'general_detriments', u'rear_units', u'shops',
#        u'busy_intersection', u'busy_road', u'wall_airconditioning',
#        u'enclosed_back_veranda', u'enclosed_front_veranda', u'entry',
#        u'enclosed_side_veranda', u'foyer', u'gallery', u'gazebo', u'gymnasium',
#        u'hall', u'house', u'lift', u'loft', u'lotdth', u'other_extra',
#        u'office', u'pantry', u'enclosed_patio', u'open_patio', u'playroom',
#        u'below_ground_pool', u'above_ground_pool', u'proximity_to_city',
#        u'_rate_per_m2_comind_pro', u'_rate_per_carbay_com_pr', u'reticulation',
#        u'tile_roof', u'iron_roof', u'rumpus_room', u'sauna', u'solarium',
#        u'utility_room', u'vestibule', u'river_views', u'ocean_views',
#        u'lake__views', u'fibro_roof'],
#       dtype='object')

# %%
# let's review what we have
df_summary(dummy_quantity)
# Out:
#                     feature  unique  count  \
# 41                   lotdth     108    339
# 50        proximity_to_city      12     25
# 15           building_depth       5     15
# 42              other_extra       4   4076
# 1           shopping_centre       4      8
# 0     airconditioned_ducted       3    148
# 62              ocean_views       3     18
# 60                vestibule       3     23
# 51  _rate_per_m2_comind_pro       3      9
# 45           enclosed_patio       3    168
# 43                   office       3    192
# 40                     loft       3    375
# 30   enclosed_front_veranda       3    180
# 29    enclosed_back_veranda       3    193
# 32    enclosed_side_veranda       3      7
# 10                   atrium       3     75
# 3           service_station       3      7
# 11                    attic       3     28
# 52  _rate_per_carbay_com_pr       2      9
# 7                  bus_stop       2      1
# 44                   pantry       2     87
# 6          secondary_school       2      1
# 46               open_patio       2    187
# 47                 playroom       2     56
# 48        below_ground_pool       2  13855
# ..                      ...     ...    ...
# 14               large_shed       2     11
# 16        building_frontage       2      1
# 39                     lift       2   2574
# 17                     bore       2  27511
# 18                   cabana       2    187
# 19  max__value_for_carcover       2      1
# 20                   cellar       2    112
# 21          close_to_church       2      4
# 22       no_airconditioning       2      4
# 23       general_detriments       2      5
# 24               rear_units       2     17
# 25                    shops       2      1
# 26        busy_intersection       2      1
# 27                busy_road       2      3
# 28     wall_airconditioning       2      2
# 13                big_rooms       2      1
# 12               extra_land       2      1
# 31                    entry       2     13
# 33                    foyer       2      2
# 34                  gallery       2     22
# 35                   gazebo       2      3
# 36                gymnasium       2     58
# 37                     hall       2     13
# 38                    house       2      1
# 64               fibro_roof       2      2
#
#                                        example_values
# 41  [nan, 28.98, 39.23, 35.0, 31.82, 37.22, 31.0, ...
# 50  [nan, 35.0, 20.0, 7.0, 17.0, 14.0, 5.0, 10.0, ...
# 15                       [nan, 74.3, 0.01, 0.5, 70.0]
# 42                               [nan, 1.0, 2.0, 1.5]
# 1                                [nan, 3.0, 2.0, 5.0]
# 0                                     [nan, 1.0, 2.0]
# 62                                    [nan, 1.0, 2.0]
# 60                                    [nan, 1.0, 2.0]
# 51                                [nan, 120.0, 115.0]
# 45                                    [nan, 1.0, 0.5]
# 43                                    [nan, 1.0, 2.0]
# 40                                    [nan, 1.0, 2.0]
# 30                                    [nan, 1.0, 2.0]
# 29                                    [nan, 1.0, 2.0]
# 32                                    [nan, 1.0, 2.0]
# 10                                    [nan, 1.0, 2.0]
# 3                                     [nan, 3.0, 2.0]
# 11                                    [nan, 1.0, 2.0]
# 52                                      [nan, 1080.0]
# 7                                          [nan, 1.0]
# 44                                         [nan, 1.0]
# 6                                          [nan, 1.0]
# 46                                         [nan, 1.0]
# 47                                         [nan, 1.0]
# 48                                         [nan, 1.0]
# ..                                                ...
# 14                                         [nan, 1.0]
# 16                                       [nan, 12.19]
# 39                                         [nan, 1.0]
# 17                                         [1.0, nan]
# 18                                         [nan, 1.0]
# 19                                         [nan, 1.0]
# 20                                         [nan, 1.0]
# 21                                         [nan, 2.0]
# 22                                         [nan, 1.0]
# 23                                         [nan, 1.0]
# 24                                         [nan, 1.0]
# 25                                         [nan, 1.0]
# 26                                         [nan, 2.0]
# 27                                         [nan, 1.0]
# 28                                         [nan, 1.0]
# 13                                       [nan, 168.0]
# 12                                         [nan, 1.0]
# 31                                         [nan, 1.0]
# 33                                         [nan, 1.0]
# 34                                         [nan, 1.0]
# 35                                         [nan, 1.0]
# 36                                         [nan, 1.0]
# 37                                         [nan, 1.0]
# 38                                        [nan, 49.0]
# 64                                         [nan, 1.0]
#
# [65 rows x 4 columns]

# %%
dummy_quantity[:5]
# Out:
#         airconditioned_ducted  shopping_centre  church  service_station  \
# ren_id
# 147                       NaN              NaN     NaN              NaN
# 317                       NaN              NaN     NaN              NaN
# 379                       NaN              NaN     NaN              NaN
# 380                       NaN              NaN     NaN              NaN
# 513                       NaN              NaN     NaN              NaN
#
#         liquor_outlet  primary_school  secondary_school  bus_stop  train_stop  \
# ren_id
# 147               NaN             NaN               NaN       NaN         NaN
# 317               NaN             NaN               NaN       NaN         NaN
# 379               NaN             NaN               NaN       NaN         NaN
# 380               NaN             NaN               NaN       NaN         NaN
# 513               NaN             NaN               NaN       NaN         NaN
#
#         public_park     ...      iron_roof  rumpus_room  sauna  solarium  \
# ren_id                  ...
# 147             NaN     ...            NaN          NaN    NaN       NaN
# 317             NaN     ...            NaN          NaN    NaN       NaN
# 379             NaN     ...            NaN          NaN    NaN       NaN
# 380             NaN     ...            NaN          NaN    NaN       NaN
# 513             NaN     ...            NaN          NaN    NaN       NaN
#
#         utility_room  vestibule  river_views  ocean_views  lake__views  \
# ren_id
# 147              NaN        NaN          NaN          NaN          NaN
# 317              NaN        NaN          NaN          NaN          NaN
# 379              NaN        NaN          NaN          NaN          NaN
# 380              NaN        NaN          NaN          NaN          NaN
# 513              NaN        NaN          NaN          NaN          NaN
#
#         fibro_roof
# ren_id
# 147            NaN
# 317            NaN
# 379            NaN
# 380            NaN
# 513            NaN
#
# [5 rows x 65 columns]

# %%
dummy_quality[:5]
# Out:
#        dual_access street_access row_access library public_pool  \
# ren_id
# 6              NaN           NaN        NaN     NaN         NaN
# 9              NaN           NaN        NaN     NaN         NaN
# 13             NaN           NaN        NaN     NaN         NaN
# 26             NaN           NaN        NaN     NaN         NaN
# 27             NaN           NaN        NaN     NaN         NaN
#
#        community_centre lot_has_city_views lot_has_river_views  \
# ren_id
# 6                   NaN                NaN                 NaN
# 9                   NaN                NaN                 NaN
# 13                  NaN                NaN                 NaN
# 26                  NaN                NaN                 NaN
# 27                  NaN                NaN                 NaN
#
#        lot_has_ocean_views lot_has_land__views          ...            \
# ren_id                                                  ...
# 6                      NaN                 NaN          ...
# 9                      NaN                 NaN          ...
# 13                     NaN                 NaN          ...
# 26                     NaN                 NaN          ...
# 27                     NaN                 NaN          ...
#
#        max_depc'n_govt_asset unit_position laneway phone_tower marina_views  \
# ren_id
# 6                        NaN           NaN     NaN         NaN          NaN
# 9                        NaN           NaN     NaN         NaN          NaN
# 13                       NaN           NaN     NaN         NaN          NaN
# 26                       NaN           NaN     NaN         NaN          NaN
# 27                       NaN           NaN     NaN         NaN          NaN
#
#        brick__fibro_walls timber_frame__fibro_w timber_framebrickfib_wa  \
# ren_id
# 6                     NaN                   NaN                     NaN
# 9                     NaN                   NaN                     NaN
# 13                    NaN                   NaN                     NaN
# 26                    NaN                   NaN                     NaN
# 27                    NaN                   NaN                     NaN
#
#        steel_frame_and_fibro weatherboardfibro_wall
# ren_id
# 6                        NaN                    NaN
# 9                        NaN                    NaN
# 13                       NaN                    NaN
# 26                       NaN                    NaN
# 27                       NaN                    NaN
#
# [5 rows x 181 columns]

# %%
# clear up some space, we are going to need it
import gc
gc.collect()
# Out:
# 200

# %% [markdown]
# ## Demographics Features

# %%
# get all the demographic features

qd1 = "select distinct on (ren_id) t1.ren_id, t1.ve_number, t3.lan_id, t3.lnp_pin, t3.sa1_7,  \
area_albers_sqm, gccsa_code_2011, sa2_5digitcode_2011, \
sa3_code_2011, sa4_code_2011, state_code_2011,  \
poacode, ra_code11, code, movie_titles, \
groups, groups_1, groups_2, \
predominant_lifestage, financial_status, worklife, area_wealth_dynamic, \
stability_indicator, featurecodegroup, feature_code  \
from "
qd2 = " t1 \
left join land_valuation_key t2 on (t1.ve_number = t2.ve_number) \
left join demographics_key t3 on (t2.lan_id = t3.lan_id) \
left join demographics t4 on (t3.sa1_7 = t4.sa1_7) "
qd3 = ";"

fullqd = qd1+' train '+qd2+' union all '+qd1+' test '+qd2+qd3

# %time demo = pd.read_sql_query(fullqd, engine)
print len(demo.ren_id.unique()), demo.shape
demo[:2]
# Out:
# CPU times: user 12.8 s, sys: 1.24 s, total: 14 s
# Wall time: 32.7 s
# 985078 (985078, 25)
#    ren_id  ve_number   lan_id   lnp_pin    sa1_7  area_albers_sqm  \
# 0       6    4485377  1385714  11521697  5110327           489217
# 1       9    3747416  4426471  11903453  5105705           225176
#
#   gccsa_code_2011  sa2_5digitcode_2011  sa3_code_2011  sa4_code_2011  \
# 0           5GPER                51103          50503            505
# 1           5GPER                51057          50403            504
#
#       ...       groups          groups_1  groups_2  predominant_lifestage  \
# 0     ...          G05  Younger Families    Family         Young families
# 1     ...          G05  Younger Families    Family         Young families
#
#      financial_status                                 worklife  \
# 0  Net worth very low  Mix of working people and professionals
# 1  Net worth very low  Mix of working people and professionals
#
#           area_wealth_dynamic                     stability_indicator  \
# 0  Affluence slowly improving  Fairly settled and less likely to move
# 1  Affluence slowly improving  Fairly settled and less likely to move
#
#   featurecodegroup feature_code
# 0                5           21
# 1                5           21
#
# [2 rows x 25 columns]

# %%
# # the sql query has no dupes, so we skip this step
# print demo.shape
# demo.drop_duplicates(['ren_id'], keep='last', inplace=True)
# print demo.shape

# %%
df_summary(demo)
# Out:
#                   feature  unique   count  \
# 0                  ren_id  985078  985078
# 2                  lan_id  289203  985020
# 1               ve_number  288444  985076
# 3                 lnp_pin  179499  414628
# 4                   sa1_7    5042  985005
# 5         area_albers_sqm    5016  985005
# 11                poacode     236  985005
# 7     sa2_5digitcode_2011     230  985005
# 14           movie_titles      51  985005
# 13                   code      51  985005
# 24           feature_code      51  985005
# 8           sa3_code_2011      36  985005
# 22    stability_indicator      20  985005
# 18  predominant_lifestage      19  985005
# 21    area_wealth_dynamic      18  985005
# 19       financial_status      13  985005
# 20               worklife      13  985005
# 9           sa4_code_2011      11  985005
# 15                 groups      11  985005
# 16               groups_1      11  985005
# 17               groups_2      11  985005
# 23       featurecodegroup      11  985005
# 12              ra_code11       7  985005
# 6         gccsa_code_2011       4  985005
# 10        state_code_2011       3  985005
#
#                                        example_values
# 0                  [6, 9, 13, 26, 27, 41, 42, 59, 61]
# 2   [1385714.0, 4426471.0, 4536296.0, 249501.0, 48...
# 1   [4485377.0, 3747416.0, 481945.0, 719761.0, 777...
# 3   [11521697.0, 11903453.0, nan, 697365.0, 517638...
# 4   [5110327.0, 5105705.0, 5104623.0, 5111821.0, 5...
# 5   [489217.0, 225176.0, 230739.0, 157454.0, 11886...
# 11  [6065.0, 6063.0, 6051.0, 6104.0, 6060.0, 6722....
# 7   [51103.0, 51057.0, 51046.0, 51118.0, 51095.0, ...
# 14  [The Parent Trap, Home Alone, Mad Max, Trading...
# 13  [21.0, 29.0, 11.0, 28.0, 39.0, 22.0, 48.0, 9.0...
# 24  [21.0, 29.0, 11.0, 28.0, 39.0, 22.0, 48.0, 9.0...
# 8   [50503.0, 50403.0, 50401.0, 50602.0, 50502.0, ...
# 22  [Fairly settled and less likely to move, More ...
# 18  [Young families, Young and old singles, Mature...
# 21  [Affluence slowly improving, Affluence increas...
# 19  [Net worth very low, High net worth, Average n...
# 20  [Mix of working people and professionals, Mix ...
# 9   [505.0, 504.0, 506.0, 508.0, 501.0, 503.0, 507...
# 15      [G05, G08, G07, G03, G09, G01, G10, G06, G02]
# 16  [Younger Families, Metro Struggle and Declinin...
# 17  [Family, Out-Takes, Mainstream, Transition, Cl...
# 23     [5.0, 8.0, 7.0, 3.0, 9.0, 1.0, 10.0, 6.0, 2.0]
# 12          [50.0, 53.0, 52.0, 51.0, 54.0, 94.0, nan]
# 6                         [5GPER, 5RWAU, 9OTER, None]
# 10                                    [5.0, 9.0, nan]

# %%
import gc 
gc.collect()
# Out:
# 176

# %%
transform_cols = [u'movie_titles', u'groups', u'groups_1', u'groups_2', u'predominant_lifestage', u'financial_status',
                  u'worklife', u'area_wealth_dynamic', u'stability_indicator']

# %%
# encode the categorical features
from sklearn import preprocessing
% time demo_encoded = demo[transform_cols].apply(preprocessing.LabelEncoder().fit_transform) 
demo_encoded[:4]
# Out:
# CPU times: user 25.8 s, sys: 116 ms, total: 25.9 s
# Wall time: 25.9 s
#    movie_titles  groups  groups_1  groups_2  predominant_lifestage  \
# 0            42       5        10         5                     13
# 1            42       5        10         5                     13
# 2            17       8         5         9                      9
# 3            20       7         2         8                      1
#
#    financial_status  worklife  area_wealth_dynamic  stability_indicator
# 0                10         4                   12                    3
# 1                10         4                   12                    3
# 2                 2         2                   12                   11
# 3                 1        10                   12                    1

# %%
# # and make the categoricals strings
# # TODO: use Pandas Categorical types?
# %time demo_encoded = demo_encoded.apply(lambda y: ['A'+str(x) if pd.notnull(x) else x for x in y])
demo_encoded[:4]
# Out:
# CPU times: user 21.5 s, sys: 391 ms, total: 21.9 s
# Wall time: 21.7 s
#   movie_titles groups groups_1 groups_2 predominant_lifestage  \
# 0          A42     A5      A10       A5                   A13
# 1          A42     A5      A10       A5                   A13
# 2          A17     A8       A5       A9                    A9
# 3          A20     A7       A2       A8                    A1
#
#   financial_status worklife area_wealth_dynamic stability_indicator
# 0              A10       A4                 A12                  A3
# 1              A10       A4                 A12                  A3
# 2               A2       A2                 A12                 A11
# 3               A1      A10                 A12                  A1

# %%
demo_categorical_features = ['sa2_5digitcode_2011', 'state_code_2011', 'poacode', 'sa1_7', 'feature_code', 
                              'sa4_code_2011', 'featurecodegroup','sa3_code_2011', 'ra_code11', 'code']

# %%
# # categorical
# demo_cat = demo[demo_categorical_features].apply(lambda y: ['A'+str(int(x)) if pd.notnull(x) else x for x in y])
demo_cat = demo[demo_categorical_features]
demo_cat[:5]
# Out:
#    sa2_5digitcode_2011  state_code_2011  poacode    sa1_7  feature_code  \
# 0                51103                5     6065  5110327            21
# 1                51057                5     6063  5105705            21
# 2                51046                5     6051  5104623            29
# 3                51118                5     6104  5111821            11
# 4                51095                5     6060  5109506            28
#
#    sa4_code_2011  featurecodegroup  sa3_code_2011  ra_code11  code
# 0            505                 5          50503         50    21
# 1            504                 5          50403         50    21
# 2            504                 8          50401         50    29
# 3            506                 7          50602         50    11
# 4            505                 3          50502         50    28

# %%
demo_orig_cols = list((set(demo.columns) - set(demo_encoded.columns)) - set(demo_cat.columns))
demo_orig_cols
# Out:
# [u've_number',
#  u'lnp_pin',
#  u'lan_id',
#  u'ren_id',
#  u'area_albers_sqm',
#  u'gccsa_code_2011']

# %%
demo.columns
# Out:
# Index([u'ren_id', u've_number', u'lan_id', u'lnp_pin', u'sa1_7',
#        u'area_albers_sqm', u'gccsa_code_2011', u'sa2_5digitcode_2011',
#        u'sa3_code_2011', u'sa4_code_2011', u'state_code_2011', u'poacode',
#        u'ra_code11', u'code', u'movie_titles', u'groups', u'groups_1',
#        u'groups_2', u'predominant_lifestage', u'financial_status', u'worklife',
#        u'area_wealth_dynamic', u'stability_indicator', u'featurecodegroup',
#        u'feature_code'],
#       dtype='object')

# %%
# we should not have lost any rows by this point
print demo.shape
print demo_encoded.shape
print demo_cat.shape
# Out:
# (985078, 25)
# (985078, 9)
# (985078, 10)

# %%
demo_all = pd.concat([demo[demo_orig_cols], demo_cat, demo_encoded], axis=1)
print demo_all.shape
# Out:
# (985078, 25)

# %%
demo_all.drop('ve_number', axis=1,inplace=True)
demo_all.set_index('ren_id', inplace=True)
demo_all[:3]
# Out:
#          lnp_pin   lan_id  area_albers_sqm gccsa_code_2011  \
# ren_id
# 6       11521697  1385714           489217           5GPER
# 9       11903453  4426471           225176           5GPER
# 13           NaN  4536296           230739           5GPER
#
#         sa2_5digitcode_2011  state_code_2011  poacode    sa1_7  feature_code  \
# ren_id
# 6                     51103                5     6065  5110327            21
# 9                     51057                5     6063  5105705            21
# 13                    51046                5     6051  5104623            29
#
#         sa4_code_2011         ...          code  movie_titles  groups  \
# ren_id                        ...
# 6                 505         ...            21           A42      A5
# 9                 504         ...            21           A42      A5
# 13                504         ...            29           A17      A8
#
#         groups_1 groups_2 predominant_lifestage financial_status worklife  \
# ren_id
# 6            A10       A5                   A13              A10       A4
# 9            A10       A5                   A13              A10       A4
# 13            A5       A9                    A9               A2       A2
#
#        area_wealth_dynamic stability_indicator
# ren_id
# 6                      A12                  A3
# 9                      A12                  A3
# 13                     A12                 A11
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Land Features

# %%
qe1 = "select distinct on (ren_id) ren_id, lan_water, lan_drainage, sub_postcode from " 
qe2 = " t1 left join land_valuation_key t2 on (t1.ve_number = t2.ve_number) \
    left join land t3 on (t2.lan_id = t3.lan_id) "

fullqe = qe1+' train '+qe2+' union all '+qe1+' test '+qe2+';'

# %time land = pd.read_sql_query(fullqe, engine)
land[:2]
# Out:
# CPU times: user 2.48 s, sys: 247 ms, total: 2.73 s
# Wall time: 12.7 s
#    ren_id lan_water lan_drainage  sub_postcode
# 0       6         N            N          6065
# 1       9         N            N          6063

# %%
print land.shape, len(train.index) + len(test.index)
if len(land.index) != len(train.index) + len(test.index):
    raise Exception('Something went wrong with the query')
# Out:
# (985078, 4) 985078

# %%
land.set_index('ren_id', inplace=True)
print land.shape
land[:2]
# Out:
# (985078, 3)
#        lan_water lan_drainage  sub_postcode
# ren_id
# 6              N            N          6065
# 9              N            N          6063

# %%
# # make postcode categorical 
#land['sub_postcode'] = ['P'+str(int(x)) if pd.notnull(x) else x for x in land.sub_postcode]
#land[:2]

# %%
# find records with all null's
print land.shape
land.isnull().sum()
# Out:
# (985078, 3)
# lan_water       8
# lan_drainage    8
# sub_postcode    8
# dtype: int64

# %%
# we only have 8 null's so we will leave them

# %% [markdown]
# ## Classification Features

# %%
qc1 = "select distinct on (ren_id) ren_id, t2.vec_cls_code, t2.cls_ve_use,  t3.cls_multi_res_ind from "
qc2 = " t1 \
    left join valuation_entities_classifications t2 \
    on (t1.ve_number = t2.ve_number and t1.ren_date_eff_from > t2.vec_date_eff_from) \
    left join valuation_entities_classifications t3 \
    on (t2.ve_number = t3.ve_number and t3.vec_date_eff_from > t2.vec_date_eff_from) "
qc3 = "group by t1.ren_id, t1.ve_number, t2.vec_cls_code, t2.cls_ve_use, t3.cls_multi_res_ind, t3.vec_date_eff_from ;"

fullqc = qc1+' train '+qc2+' union all '+qc1+' test '+qc2+qc3

# %time classf = pd.read_sql_query(fullqc, engine)
classf[:2]
# Out:
# CPU times: user 2.39 s, sys: 291 ms, total: 2.68 s
# Wall time: 39.7 s
#    ren_id  vec_cls_code cls_ve_use cls_multi_res_ind
# 0       6           105          V                 N
# 1       9            75          R              None

# %%
print classf.shape
if len(classf.index) != len(train.index) + len(test.index):
    raise Exception('Bad query for classification features')
# Out:
# (985078, 4)

# %%
classf[:10]
# Out:
#    ren_id  vec_cls_code cls_ve_use cls_multi_res_ind
# 0       6           105          V                 N
# 1       9            75          R              None
# 2      13            60          R              None
# 3      26            87          R              None
# 4      27            75          R              None
# 5      41            10          R              None
# 6      42            10          R              None
# 7      59            10          R              None
# 8      61            50          R              None
# 9      65            10          R              None

# %%
classf.cls_ve_use.value_counts()
# Out:
# R    892371
# V     85450
# C      1410
# M       104
# I        66
# F        52
# Name: cls_ve_use, dtype: int64

# %%
# # make categorical 
classf['vec_cls_code'] = ['C'+str(int(x)) if pd.notnull(x) else x for x in classf.vec_cls_code]
classf[:2]
# Out:
#    ren_id vec_cls_code cls_ve_use cls_multi_res_ind
# 0       6         C105          V                 N
# 1       9          C75          R              None

# %%
classf.cls_multi_res_ind.unique()
# Out:
# array([u'N', None, u'Y'], dtype=object)

# %%
classf.set_index('ren_id', inplace=True)
classf[:2]
# Out:
#        vec_cls_code cls_ve_use cls_multi_res_ind
# ren_id
# 6              C105          V                 N
# 9               C75          R              None

# %%
print classf.shape
classf.isnull().sum()
# Out:
# (985078, 3)
# vec_cls_code           5625
# cls_ve_use             5625
# cls_multi_res_ind    806627
# dtype: int64

# %%
# # impute , not just yet
# classf.loc[classf.cls_multi_res_ind.isnull(),'cls_multi_res_ind'] = 'N'

# %%
import gc
gc.collect()
# Out:
# 125

# %% [markdown]
# ## Distances

# %%
qf1 = "select distinct on (ren_id) ren_id, pin, \
    distance_coast,distance_hospital,distance_school_poly,distance_reserve,distance_waterbody,\
    distance_arterialroad,distance_gpo,distance_golfcourse,distance_university,distance_freeway,\
    distance_shoppingcentre,distance_trainstation,distance_railline,distance_airport from " 
qf2 = " t1 left join land_valuation_key t2 on (t1.ve_number = t2.ve_number) \
    left join land_pins t3 on (t2.lan_id = t3.lan_id and t3.lnp_pin is not null) \
    left join distances t4 on (t3.lnp_pin = t4.pin) "

fullqf = qf1+' train '+qf2+' union all '+qf1+' test '+qf2+';'

# %time distances = pd.read_sql_query(fullqf, engine)
print distances.shape
distances[:5]
# Out:
# CPU times: user 4.32 s, sys: 687 ms, total: 5 s
# Wall time: 7min 37s
# (985078, 16)
#    ren_id       pin  distance_coast  distance_hospital  distance_school_poly  \
# 0       6  11521697           10052               5940                   795
# 1       9  11903453           16385               6511                   739
# 2      13       NaN             NaN                NaN                   NaN
# 3      26       NaN             NaN                NaN                   NaN
# 4      27       NaN             NaN                NaN                   NaN
#
#    distance_reserve  distance_waterbody  distance_arterialroad  distance_gpo  \
# 0               178                1307                    679         15263
# 1               168                 487                     57         11984
# 2               NaN                 NaN                    NaN           NaN
# 3               NaN                 NaN                    NaN           NaN
# 4               NaN                 NaN                    NaN           NaN
#
#    distance_golfcourse  distance_university  distance_freeway  \
# 0                 1668                 5116              6072
# 1                 1807                 6674             10253
# 2                  NaN                  NaN               NaN
# 3                  NaN                  NaN               NaN
# 4                  NaN                  NaN               NaN
#
#    distance_shoppingcentre  distance_trainstation  distance_railline  \
# 0                      652                   6186               6082
# 1                        0                   5206               2382
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
#
#    distance_airport
# 0             15720
# 1              7588
# 2               NaN
# 3               NaN
# 4               NaN

# %%
if len(distances.index) != len(train.index) + len(test.index):
    raise Exception('Bad query for distances features')

# %%
distances.set_index('ren_id', inplace=True)
distances[:2]
# Out:
#              pin  distance_coast  distance_hospital  distance_school_poly  \
# ren_id
# 6       11521697           10052               5940                   795
# 9       11903453           16385               6511                   739
#
#         distance_reserve  distance_waterbody  distance_arterialroad  \
# ren_id
# 6                    178                1307                    679
# 9                    168                 487                     57
#
#         distance_gpo  distance_golfcourse  distance_university  \
# ren_id
# 6              15263                 1668                 5116
# 9              11984                 1807                 6674
#
#         distance_freeway  distance_shoppingcentre  distance_trainstation  \
# ren_id
# 6                   6072                      652                   6186
# 9                  10253                        0                   5206
#
#         distance_railline  distance_airport
# ren_id
# 6                    6082             15720
# 9                    2382              7588

# %%
import gc
gc.collect()
# Out:
# 797

# %% [markdown]
# # Big Merge

# %%
allset = train.append(test)
if len(allset) != (len(train) + len(test)):
    raise Exception('Failure in append')

allset[:2]
# Out:
#          ren_base_rent ren_date_eff_from ren_lease_length  ve_number
# ren_id
# 1579258            280        1990-02-13              NaN    4807702
# 1203979            115        1990-04-13              NaN     332135

# %%
# so how many columns do we have?
allcols =  len(allset.columns) + len(demo_all.columns) + len(quantity_features.columns) \
    + len(quality_features.columns) + len(dummy_quantity.columns) + len(dummy_quality.columns) \
    + len(land.columns) + len(classf.columns) + len(distances.columns)
allcols
# Out:
# 370

# %%
# merge into one big table
allup = pd.concat([allset, demo_all, quantity_features, quality_features, dummy_quantity, dummy_quality, 
           land, classf, distances], axis=1, join_axes=[allset.index])

print allset.shape, allup.shape
if (len(allset.index) != len(allup.index)) | (len(allup.columns) != allcols):
    raise Exception('Not sure this merge is good')
# Out:
# (985078, 4) (985078, 370)

# %%
allup[:5]
# Out:
#          ren_base_rent ren_date_eff_from ren_lease_length  ve_number  lnp_pin  \
# ren_id
# 1579258            280        1990-02-13              NaN    4807702   360151
# 1203979            115        1990-04-13              NaN     332135      NaN
# 1431889            150        1990-04-14              NaN    1647835      NaN
# 1025129            100        1990-09-21              NaN     663393      NaN
# 5191246             80        1990-10-03              NaN    2511508   682741
#
#           lan_id  area_albers_sqm gccsa_code_2011  sa2_5digitcode_2011  \
# ren_id
# 1579258   650100           131756           5GPER                51188
# 1203979   560980           171145           5GPER                51177
# 1431889  2897191           341092           5RWAU                51210
# 1025129  4998891           159324           5GPER                51119
# 5191246  4666462           403410           5RWAU                51199
#
#          state_code_2011       ...         distance_waterbody  \
# ren_id                         ...
# 1579258                5       ...                        434
# 1203979                5       ...                        NaN
# 1431889                5       ...                        NaN
# 1025129                5       ...                        NaN
# 5191246                5       ...                       1816
#
#          distance_arterialroad  distance_gpo  distance_golfcourse  \
# ren_id
# 1579258                    531         39071                 2980
# 1203979                    NaN           NaN                  NaN
# 1431889                    NaN           NaN                  NaN
# 1025129                    NaN           NaN                  NaN
# 5191246                    441        551513                 2739
#
#          distance_university  distance_freeway  distance_shoppingcentre  \
# ren_id
# 1579258                 1868              9458                      656
# 1203979                  NaN               NaN                      NaN
# 1431889                  NaN               NaN                      NaN
# 1025129                  NaN               NaN                      NaN
# 5191246                   72            547169                      351
#
#          distance_trainstation distance_railline distance_airport
# ren_id
# 1579258                   2584              2566             6856
# 1203979                    NaN               NaN              NaN
# 1431889                    NaN               NaN              NaN
# 1025129                    NaN               NaN              NaN
# 5191246                   1022               999             2965
#
# [5 rows x 370 columns]

# %%
# # we need to re-impute all the new rows!

# allup.loc[:,quantity_features.columns] = allup.loc[:,quantity_features.columns].fillna(0)
# allup.loc[:,quality_features.columns] = allup.loc[:,quality_features.columns].fillna('0')
# allup.loc[:,dummy_quantity.columns] = allup.loc[:,dummy_quantity.columns].fillna(0)
# allup.loc[:,dummy_quality.columns] = allup.loc[:,dummy_quality.columns].fillna('0')
# allup.loc[allup.cls_multi_res_ind.isnull(),'cls_multi_res_ind'] = 'N'

# %%
allup.columns.values
# Out:
# array(['ren_base_rent', 'ren_date_eff_from', 'ren_lease_length',
#        've_number', u'lnp_pin', u'lan_id', u'area_albers_sqm',
#        u'gccsa_code_2011', u'sa2_5digitcode_2011', u'state_code_2011',
#        u'poacode', u'sa1_7', u'feature_code', u'sa4_code_2011',
#        u'featurecodegroup', u'sa3_code_2011', u'ra_code11', u'code',
#        u'movie_titles', u'groups', u'groups_1', u'groups_2',
#        u'predominant_lifestage', u'financial_status', u'worklife',
#        u'area_wealth_dynamic', u'stability_indicator', 'activity_room',
#        'airconditioned', 'house_area', 'office_area_1', 'shop_area',
#        'store_room_area_1', 'warehouse_area_1', 'factory_area_1',
#        'any_other_area', 'basement_area', 'shed_area_1', 'total_area',
#        'mezzanine_area', 'workshop_area_1', 'bar', 'bath_room', 'bedrooms',
#        'single_bedrooms', 'carbay_under_cover', 'tandem_carbay',
#        'open_car_bay', 'carport_under_main_roof', 'carport_attached',
#        'carport_detached', 'dining_room', 'dressing_room',
#        'effective_rooms', 'ensuite', 'excess_land', 'family_room',
#        'frontage_of_block', 'fronts_onto_lake', 'games__room',
#        'detached_gamesroom', 'garage_under_main_roof', 'garage_attached',
#        'garage_detached', 'guest_room', 'kennels', 'kitchen', 'laundry',
#        'lounge_room', 'meals_area', 'music_room', 'other_rooms',
#        'plate_height', 'parents__retreat', 'sleep_out', 'sewing_room',
#        'shed', 'sitting_room', 'spa_room', 'stable', 'store_room',
#        'storey', 'studio', 'study', 'sun_room', 'television_room',
#        'tennis_court', 'number_of_units', 'toilet', 'walk_in_robe',
#        'workshop', 'effective_bed_count', 'ven_land_area', 'theatre_room',
#        'hall_area', 'jetty', 'alfresco_room', 'kitchenette',
#        'area_of_sheds', 'scullery', 'condition', 'year_built',
#        'year_effective', 'airconditioned_ducted', 'shopping_centre',
#        'church', 'service_station', 'liquor_outlet', 'primary_school',
#        'secondary_school', 'bus_stop', 'train_stop', 'public_park',
#        'atrium', 'attic', 'extra_land', 'big_rooms', 'large_shed',
#        'building_depth', 'building_frontage', 'bore', 'cabana',
#        'max__value_for_carcover', 'cellar', 'close_to_church',
#        'no_airconditioning', 'general_detriments', 'rear_units', 'shops',
#        'busy_intersection', 'busy_road', 'wall_airconditioning',
#        'enclosed_back_veranda', 'enclosed_front_veranda', 'entry',
#        'enclosed_side_veranda', 'foyer', 'gallery', 'gazebo', 'gymnasium',
#        'hall', 'house', 'lift', 'loft', 'lotdth', 'other_extra', 'office',
#        'pantry', 'enclosed_patio', 'open_patio', 'playroom',
#        'below_ground_pool', 'above_ground_pool', 'proximity_to_city',
#        '_rate_per_m2_comind_pro', '_rate_per_carbay_com_pr',
#        'reticulation', 'tile_roof', 'iron_roof', 'rumpus_room', 'sauna',
#        'solarium', 'utility_room', 'vestibule', 'river_views',
#        'ocean_views', 'lake__views', 'fibro_roof', 'dual_access',
#        'street_access', 'row_access', 'library', 'public_pool',
#        'community_centre', 'lot_has_city_views', 'lot_has_river_views',
#        'lot_has_ocean_views', 'lot_has_land__views', 'lot_has_hill__views',
#        'lot_looks_over_a_park', 'general_attributes', 'age_of_buildings',
#        '_community_facilities', 'river_frontage', 'canals_frontage',
#        'close_to_park', 'boat_shed', 'cold_room', 'canal_frontage',
#        'character', 'change_room', 'steel_frame_and_iron_wall',
#        'iron_walls', 'stone_walls', 'concrete_block_walls', 'brick__walls',
#        'steel_frame', 'timber_frame', 'brick_veneer',
#        'weather_board_walls', 'other', 'brick_clad', 'brick__iron_walls',
#        'stucco_walls', 'brick_walls_timber_frame',
#        'brick__weathboard_walls', 'fibro_walls', 'rammed_earth',
#        'precast_concrete_walls', 'limestone', 'design', 'block_of_flats',
#        'public_toilet', 'sump', 'hotel', 'transformer', 'kindergarden',
#        'infant_health_centre', 'telephone_box', 'traffic_lights',
#        'bus_shelter', 'school', 'non_conforming_use', 'caravan_park',
#        'bmx_track', 'car_park', 'drain', 'surgery', 'lights',
#        'industrial_property', 'railway', 'recreation_centre', 'depot',
#        'hospital', 'poor_access', 'inferior_location', 'power_station',
#        'oval', 'public_hall', 'cemetary', 'commercial_building',
#        'traffic_noise', 'traffic_island', 'graveyard', 'isolated_location',
#        'property_exposed_to_dust', 'close_to_commercial_area',
#        'next_to_bowling_club', 'age_of_building', 'adj_public_open_space',
#        'pedestrian_access_way', 'small_rooms', 'freeway', 'upper_floor',
#        'tennissquash_courts', 'old_age_home', 'club', 'size_of_block',
#        'community_facilities', 'restaurant', 'police_station',
#        'pump_station', '_shopping_centre', 'gaol', 'flood_prone',
#        'on_an_island_no_vehicle_a', 'less_than_norm_bedrooms',
#        'construction_type', 'reduced_area', 'common_walls',
#        'buildings_lack_utility', 'low_lying_land', 'bulk_allowance',
#        'overhead_power_lines', 'high_elevation', 'low__elevation',
#        'kerb_and_drainage', 'not_kerb_and_drainage', 'corner_location',
#        'location_of_property', 'location', 'bitumen', 'gravel_road',
#        'street_road_type', 'culdesac', 'dual_c_way', 'above_road',
#        'below_road', 'aluminium_roof', 'other_roof_type',
#        'decromastic_tile', 'metal_decking', 'spur_access',
#        'storm_water_available', 'shade_house', 'no_slope',
#        'front_to_rear_slope', 'rear_to_front_slope', 'wet_soil',
#        'dry_soil', 'rocky_soil', 'sandy_soil', 'gravel_soil',
#        'other__soil', 'street_allowance', 'street_parking', 'horse_stall',
#        'standard_of_finish', 'character_standard_of_fin',
#        'unit_position_front', 'unit_position_rear', 'unit_position_corner',
#        'unit_position__corner', 'unit_position_ground',
#        'unit_position_first_floor', 'unit_position_second_floo',
#        'unit_position_third_floor', 'unit_position_upper_floor',
#        'unit_position_middle', 'city_views', 'land_views', 'hill_views',
#        'park_views', 'valley_views', 'harbour_views', 'estuary_views',
#        'general_views', 'water_tank', 'flat', 'cross_fall_left_to_right',
#        'cross_fall_right_to_left', 'smaller_lot_size', 'unusual_design',
#        'sporting_facility', 'located_at_rear', 'traffic_noisesafety',
#        'no_onsite_carpark', "restricted_to_over_55's", 'studio_detached',
#        "max_depc'n_govt_asset", 'unit_position', 'laneway', 'phone_tower',
#        'marina_views', 'brick__fibro_walls', 'timber_frame__fibro_w',
#        'timber_framebrickfib_wa', 'steel_frame_and_fibro',
#        'weatherboardfibro_wall', u'lan_water', u'lan_drainage',
#        u'sub_postcode', u'vec_cls_code', u'cls_ve_use',
#        u'cls_multi_res_ind', u'pin', u'distance_coast',
#        u'distance_hospital', u'distance_school_poly', u'distance_reserve',
#        u'distance_waterbody', u'distance_arterialroad', u'distance_gpo',
#        u'distance_golfcourse', u'distance_university', u'distance_freeway',
#        u'distance_shoppingcentre', u'distance_trainstation',
#        u'distance_railline', u'distance_airport'], dtype=object)

# %%
import gc
gc.collect()
# Out:
# 26

# %% [markdown]
# # OUTPUT

# %%
# split train and test again
train_final = allup.loc[train.index].copy()
test_final = allup.loc[test.index].copy()

# %%
print allup.shape
print train_final.shape
print test_final.shape
# Out:
# (985078, 370)
# (834570, 370)
# (150508, 370)

# %%
train_final.to_csv('train_full.csv')

# %%
test_final.to_csv('test_full.csv')

# %%
allup.to_csv('train_test_full.csv')

# %%
end_time = pd.datetime.now()
elapsed_time = end_time - start_time
print elapsed_time
# Out:
# 2:35:32.085424

# %%
gc.collect()
# Out:
# 0
