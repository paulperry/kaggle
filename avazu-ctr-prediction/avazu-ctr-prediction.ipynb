# %%
import pandas as pd
import csv 
import matplotlib.pyplot as plt
# %pylab inline

#pd.options.display.mpl_style = 'default'  # for grey backgrounds ggplot style
pd.options.display.mpl_style = None
plt.rcParams['figure.figsize'] = (10,10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_7 = pd.read_csv("predict7.csv")
df_7[:2]
# Out:
#                      id  click
# 0  10000174058809263569  0.110
# 1  10000182526920855428  0.291

# %%
df_p2 = pd.read_csv("predict_p2.csv")
df_p2[:2]
# Out:
#                      id     click
# 0  10000174058809263569  0.057437
# 1  10000182526920855428  0.179535

# %%
plt.scatter(list(df_7.click), list(df_p2.click), marker=".", s=1 )

# %%
df_blend1 = df_7.copy()
df_blend1.click = (df_7.click + df_p2.click) / 2.0
df_blend1[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.083718
# 1  10000182526920855428  0.235268
# 2  10000554139829213984  0.343608
# 3  10001094637809798845  0.054376
# 4  10001377041558670745  0.293104

# %%
df_blend1.to_csv("predict_blend1.csv",index=False, mode="wb")

# %%
df_9 = pd.read_csv("predict9.gz", compression='gzip')
df_9[:2]
# Out:
#                      id  click
# 0  10000174058809263569  0.107
# 1  10000182526920855428  0.278

# %%
plt.scatter(list(df_7.click), list(df_9.click), marker=".", s=1 )

# %%
df_blend4 = df_7.copy()
df_blend4.click = (df_7.click + df_9.click) / 2.0
df_blend4[:5]
# Out:
#                      id   click
# 0  10000174058809263569  0.1085
# 1  10000182526920855428  0.2845
# 2  10000554139829213984  0.4060
# 3  10001094637809798845  0.0820
# 4  10001377041558670745  0.2945

# %%
df_blend4.to_csv("predict_blend4.csv",index=False, mode="wb")

# %% [markdown]
# ## DR model

# %%
# read all the prediction parts from file
df_dr1 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test1.csv.csv')
df_dr2 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test2.csv.csv')
df_dr3 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test3.csv.csv')
df_dr4 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test4.csv.csv')
df_dr5 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test5.csv.csv')
df_dr6 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test6.csv.csv')
df_dr7 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test7.csv.csv')
df_dr8 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test8.csv.csv')
df_dr9 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test9.csv.csv')
df_dr10 = pd.read_csv('avazu_GLM_Blender_(2+14+15)_(71)_50.17_Informative_Features_test10.csv.csv')

# %%
# append them together
df_dr_prediction = list(df_dr1.Prediction)
df_dr_prediction.extend(list(df_dr2.Prediction))
df_dr_prediction.extend(list(df_dr3.Prediction))
df_dr_prediction.extend(list(df_dr4.Prediction))
df_dr_prediction.extend(list(df_dr5.Prediction))
df_dr_prediction.extend(list(df_dr6.Prediction))
df_dr_prediction.extend(list(df_dr7.Prediction))
df_dr_prediction.extend(list(df_dr8.Prediction))
df_dr_prediction.extend(list(df_dr9.Prediction))
df_dr_prediction.extend(list(df_dr10.Prediction))
df_dr_prediction = pd.DataFrame(df_dr_prediction, columns=['click'])
df_dr_prediction[:2]
# Out:
#       click
# 0  0.058180
# 1  0.166819

# %%
df_dr = pd.read_csv('sampleSubmission')
df_dr[:2]
# Out:
#                      id  click
# 0  10000174058809263569    0.5
# 1  10000182526920855428    0.5

# %%
print len(df_dr)
print len(df_dr_prediction)
# Out:
# 4577464
# 4577464

# %%
df_dr.click = df_dr_prediction.click
df_dr[:2]
# Out:
#                      id     click
# 0  10000174058809263569  0.058180
# 1  10000182526920855428  0.166819

# %%
df_dr.to_csv("predict_dr1.csv",index=False, mode="wb")

# %%
plt.scatter(list(df_7.click), list(df_dr.click), marker=".", s=1 )

# %%
df_blend2 = df_7.copy()
df_blend2.click = (df_7.click + df_dr.click) / 2.0
df_blend2[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.084090
# 1  10000182526920855428  0.228910
# 2  10000554139829213984  0.290322
# 3  10001094637809798845  0.058510
# 4  10001377041558670745  0.283298

# %%
df_blend2.to_csv("predict_dr1_blend.csv",index=False, mode="wb")

# %%
df_blend3 = df_blend1.copy()
df_blend3.click = (df_blend1.click + df_dr.click) / 2.0
df_blend3[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.070949
# 1  10000182526920855428  0.201043
# 2  10000554139829213984  0.255127
# 3  10001094637809798845  0.045198
# 4  10001377041558670745  0.282350

# %%
df_blend3.to_csv("predict_dr3_blend.csv",index=False, mode="wb")

# %%
df_12 = pd.read_csv("predict12.gz", compression='gzip')
df_12[:2]
# Out:
#                      id  click
# 0  10000174058809263569  0.114
# 1  10000182526920855428  0.276

# %%
df_15 = pd.read_csv("predict15.gz", compression='gzip')
df_15[:2]
# Out:
#                      id  click
# 0  10000174058809263569  0.107
# 1  10000182526920855428  0.266

# %%
plt.scatter(list(df_7.click), list(df_15.click), marker=".", s=1 )

# %%
df_blend15 = df_7.copy()
df_blend15.click = (df_7.click + df_15.click) / 2.0
df_blend15[:5]
# Out:
#                      id   click
# 0  10000174058809263569  0.1085
# 1  10000182526920855428  0.2785
# 2  10000554139829213984  0.4115
# 3  10001094637809798845  0.0850
# 4  10001377041558670745  0.2850

# %%
df_blend15.to_csv("predict_blend15.csv",index=False, mode="wb")

# %%
plt.scatter(list(df_blend1.click), list(df_15.click), marker=".", s=1 )

# %%
df_blend16 = df_blend1.copy()
df_blend16.click = (df_blend1.click + df_15.click) / 2.0
df_blend16[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.095359
# 1  10000182526920855428  0.250634
# 2  10000554139829213984  0.376304
# 3  10001094637809798845  0.071688
# 4  10001377041558670745  0.284052

# %%
df_blend16.to_csv("predict_blend16.csv",index=False, mode="wb")

# %%
df_blend17 = df_blend1.copy()
df_blend17.click = (df_7.click * .2 + df_15.click * .2 + df_9.click * .2 + df_12.click * .2 + df_dr.click * .2) 
df_blend17[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.099236
# 1  10000182526920855428  0.255564
# 2  10000554139829213984  0.353129
# 3  10001094637809798845  0.073804
# 4  10001377041558670745  0.284319

# %%
df_blend17.to_csv("predict_blend17.csv",index=False, mode="wb")

# %%
# logloss from Kaggle leaderboard for predict7, 9, 12, 15, and dr in order
scores = [0.3926787, 0.3932927, 0.3934123, 0.3935856, 0.3979479] 
scores = scores / sum(scores)
sum(scores)
# Out:
# 1.0

# %%
df_blend18 = df_blend1.copy()
df_blend18.click = (df_7.click * scores[0] + 
                    df_9.click * scores[1] + 
                    df_12.click * scores[2]+ 
                    df_15.click * scores[3]+
                    df_dr.click * scores[4]) 
df_blend18[:5]
# Out:
#                      id     click
# 0  10000174058809263569  0.099138
# 1  10000182526920855428  0.255346
# 2  10000554139829213984  0.352679
# 3  10001094637809798845  0.073715
# 4  10001377041558670745  0.284285

# %%
df_blend18.to_csv("predict_blend18.csv",index=False, mode="wb")

# %%
df_13 = pd.read_csv("predict13.gz", compression='gzip')
df_13[:2]
# Out:
#                      id  click
# 0  10000174058809263569  0.137
# 1  10000182526920855428  0.301

# %%
plt.scatter(list(df_15.click), list(df_13.click), marker=".", s=1 )

# %%
plt.scatter(list(df_7.click), list(df_9.click), marker=".", s=1 )

# %%
plt.scatter(list(df_7.click), list(df_12.click), marker=".", s=1 )

# %%
plt.scatter(list(df_7.click), list(df_13.click), marker=".", s=1 )

# %%
plt.scatter(list(df_9.click), list(df_12.click), marker=".", s=1 )

# %%
plt.scatter(list(df_9.click), list(df_13.click), marker=".", s=1 )

# %%
plt.scatter(list(df_15.click), list(df_12.click), marker=".", s=1 )

# %%
df_blend19 = df_blend1.copy()
df_blend19.click = (df_9.click * 0.25 + df_12.click * 0.25 + df_15.click * 0.25 + df_13.click * 0.25) 
df_blend19[:5]
# Out:
#                      id    click
# 0  10000174058809263569  0.11625
# 1  10000182526920855428  0.28025
# 2  10000554139829213984  0.39975
# 3  10001094637809798845  0.08400
# 4  10001377041558670745  0.29425

# %%
plt.scatter(list(df_7.click), list(df_blend19.click), marker=".", s=1 )

# %%
plt.scatter(list(df_7.click), list(df_blend16.click), marker=".", s=1 )

# %%
plt.scatter(list(df_7.click), list(df_p2.click), marker=".", s=1 )

# %%
plt.scatter(list(df_9.click), list(df_blend1.click), marker=".", s=1 )

# %%
df_blend20 = df_blend1.copy()
df_blend20.click = ( df_15.click * 0.5 + df_13.click * 0.5) 
df_blend20[:5]
# Out:
#                      id   click
# 0  10000174058809263569  0.1220
# 1  10000182526920855428  0.2835
# 2  10000554139829213984  0.4115
# 3  10001094637809798845  0.0865
# 4  10001377041558670745  0.2985

# %%
plt.scatter(list(df_7.click), list(df_blend20.click), marker=".", s=1 )

# %%
df_blend21 = df_blend1.copy()
df_blend21.click = ( df_7.click * 0.5 + df_blend20.click * 0.5) 
df_blend21[:5]
# Out:
#                      id    click
# 0  10000174058809263569  0.11600
# 1  10000182526920855428  0.28725
# 2  10000554139829213984  0.41275
# 3  10001094637809798845  0.08375
# 4  10001377041558670745  0.29675

# %%
df_blend21.to_csv("predict_blend21.csv",index=False, mode="wb")
