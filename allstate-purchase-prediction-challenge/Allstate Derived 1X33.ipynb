# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
csv_dir = '/Users/Paul/Desktop/Allstate/'
df_derived = pd.read_csv(csv_dir + 'train_derived.csv')

# %%
df_derived_1X33 = df_derived.query('A==1 & C==3 & D==3')

# %%
print len(df_derived)
print len(df_derived_1X33)
# Out:
# 97009
# 25001

# %%
df_derived_1X33.set_index('customer_ID',inplace=True)
df_derived_1X33[:5]
# Out:
#              shopping_pt  record_type  day   time state  location  group_size  \
# customer_ID
# 10000026               3            0    1  09:10    OH     10028           2
# 10000039               8            0    2  13:12    OH     10041           1
# 10000040               3            0    2  11:49    KS     10042           1
# 10000042               3            0    0  11:10    FL     10044           3
# 10000043               6            0    4  09:23    NY     10045           1
#
#              homeowner  car_age car_value  risk_factor  age_oldest  \
# customer_ID
# 10000026             1        5         d            3          59
# 10000039             1        4         f          NaN          49
# 10000040             1        6         e          NaN          26
# 10000042             0        9         e            3          65
# 10000043             1        3         f            2          51
#
# ...

# %%
df_derived_1X33.to_csv(csv_dir + 'train_1X33.csv', mode='wb')
